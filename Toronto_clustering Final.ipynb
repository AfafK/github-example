# %%
import numpy as np  # useful for many scientific computing in Python
import pandas as pd # primary data structure library

# %% [markdown]
# # Reading Toronto postal code file data into a dataframe

# %%
df_tor = pd.read_excel('Toronto_postalcodes.xlsx')

# %% [markdown]
# # Ignore cells with a borough that is Not assigned.

# %%
df_tor = df_tor[df_tor.Neighborhood.notnull()]

# %% [markdown]
# # Displaying dataframe

# %%
df_tor.head()
# Out:
#   Postal code           Borough                                  Neighborhood
# 2         M3A        North York                                     Parkwoods
# 3         M4A        North York                              Victoria Village
# 4         M5A  Downtown Toronto                    Regent Park / Harbourfront
# 5         M6A        North York             Lawrence Manor / Lawrence Heights
# 6         M7A  Downtown Toronto  Queen's Park / Ontario Provincial Government

# %% [markdown]
# # Print the number of rows

# %%
df_tor.shape
# Out:
# (103, 3)

# %% [markdown]
# # Read file with coordinates into a dataframe

# %%
df_cor = pd.read_csv('Geospatial_Coordinates.csv')
df_cor.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %% [markdown]
# # Add Latitude & longitude columns to Toronto Dataframe

# %%
df_tor['Latitude'] =""

# %%
df_tor['Longitude'] =""

# %%
df_tor = df_tor.set_index("Postal code").sort_index()

# %%
df_tor.head()
# Out:
#                  Borough                              Neighborhood Latitude  \
# Postal code
# M1B          Scarborough                           Malvern / Rouge
# M1C          Scarborough  Rouge Hill / Port Union / Highland Creek
# M1E          Scarborough       Guildwood / Morningside / West Hill
# M1G          Scarborough                                    Woburn
# M1H          Scarborough                                 Cedarbrae
#
#             Longitude
# Postal code
# M1B
# M1C
# M1E
# M1G
# M1H

# %%
df_cor = df_cor.set_index("Postal Code").sort_index()

# %%
df_cor.head()
# Out:
#               Latitude  Longitude
# Postal Code
# M1B          43.806686 -79.194353
# M1C          43.784535 -79.160497
# M1E          43.763573 -79.188711
# M1G          43.770992 -79.216917
# M1H          43.773136 -79.239476

# %%
df_tor['Latitude'] = np.where(df_tor.index == df_cor.index, df_cor['Latitude'], "")

# %%
df_tor['Longitude'] = np.where(df_tor.index == df_cor.index, df_cor['Longitude'], "")

# %%
df_tor.head()
# Out:
#                  Borough                              Neighborhood  \
# Postal code
# M1B          Scarborough                           Malvern / Rouge
# M1C          Scarborough  Rouge Hill / Port Union / Highland Creek
# M1E          Scarborough       Guildwood / Morningside / West Hill
# M1G          Scarborough                                    Woburn
# M1H          Scarborough                                 Cedarbrae
#
#                        Latitude           Longitude
# Postal code
# M1B          43.806686299999996  -79.19435340000001
# M1C                  43.7845351  -79.16049709999999
# M1E                  43.7635726         -79.1887115
# M1G                  43.7709921  -79.21691740000001
# M1H                   43.773136  -79.23947609999999

# %%
df_tor = df_tor.reset_index()

# %%
df_tor.head()
# Out:
#   Postal code      Borough                              Neighborhood  \
# 0         M1B  Scarborough                           Malvern / Rouge
# 1         M1C  Scarborough  Rouge Hill / Port Union / Highland Creek
# 2         M1E  Scarborough       Guildwood / Morningside / West Hill
# 3         M1G  Scarborough                                    Woburn
# 4         M1H  Scarborough                                 Cedarbrae
#
#              Latitude           Longitude
# 0  43.806686299999996  -79.19435340000001
# 1          43.7845351  -79.16049709999999
# 2          43.7635726         -79.1887115
# 3          43.7709921  -79.21691740000001
# 4           43.773136  -79.23947609999999

# %% [markdown]
# # Filter neighbourhood by Toronto

# %%
df_tor1 = df_tor[df_tor.Borough.str.contains('Toronto',case=False)]
df_tor1.head()
# Out:
#    Postal code          Borough                     Neighborhood  \
# 37         M4E     East Toronto                      The Beaches
# 41         M4K     East Toronto    The Danforth West / Riverdale
# 42         M4L     East Toronto  India Bazaar / The Beaches West
# 43         M4M     East Toronto                  Studio District
# 44         M4N  Central Toronto                    Lawrence Park
#
#              Latitude           Longitude
# 37  43.67635739999999         -79.2930312
# 41         43.6795571          -79.352188
# 42         43.6689985  -79.31557159999998
# 43         43.6595255          -79.340923
# 44         43.7280205         -79.3887901

# %% [markdown]
# # Import all necessary libraries

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.

# %%
df_tor1.groupby('Borough').count()
# Out:
#                   Postal code  Neighborhood  Latitude  Longitude
# Borough
# Central Toronto             9             9         9          9
# Downtown Toronto           19            19        19         19
# East Toronto                5             5         5          5
# West Toronto                6             6         6          6

# %%
# one hot encoding
df_onehot = pd.get_dummies(df_tor1['Neighborhood'], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
df_onehot['Borough'] = df_tor1['Borough']

# move neighborhood column to the first column
fixed_columns = [df_onehot.columns[-1]] + list(df_onehot.columns[:-1])
df_onehot = df_onehot[fixed_columns]

df_onehot.head()
# Out:
#             Borough  Berczy Park  \
# 37     East Toronto            0
# 41     East Toronto            0
# 42     East Toronto            0
# 43     East Toronto            0
# 44  Central Toronto            0
#
#     Brockton / Parkdale Village / Exhibition Place  \
# 37                                               0
# 41                                               0
# 42                                               0
# 43                                               0
# 44                                               0
#
#     Business reply mail Processing Centre  \
# 37                                      0
# 41                                      0
# 42                                      0
# 43                                      0
# 44                                      0
#
#     CN Tower / King and Spadina / Railway Lands / Harbourfront West / Bathurst Quay / South Niagara / Island airport  \
# 37                                                  0
# 41                                                  0
# 42                                                  0
# 43                                                  0
# 44                                                  0
#
#     Central Bay Street  Christie  Church and Wellesley  \
# 37                   0         0                     0
# 41                   0         0                     0
# 42                   0         0                     0
# 43                   0         0                     0
# 44                   0         0                     0
#
#     Commerce Court / Victoria Hotel  Davisville  Davisville North  \
# 37                                0           0                 0
# 41                                0           0                 0
# 42                                0           0                 0
# 43                                0           0                 0
# 44                                0           0                 0
#
#     Dufferin / Dovercourt Village  First Canadian Place / Underground city  \
# 37                              0                                        0
# 41                              0                                        0
# 42                              0                                        0
# 43                              0                                        0
# 44                              0                                        0
#
#     Forest Hill North & West  Garden District / Ryerson  \
# 37                         0                          0
# 41                         0                          0
# 42                         0                          0
# 43                         0                          0
# 44                         0                          0
#
#     Harbourfront East / Union Station / Toronto Islands  \
# 37                                                  0
# 41                                                  0
# 42                                                  0
# 43                                                  0
# 44                                                  0
#
#     High Park / The Junction South  India Bazaar / The Beaches West  \
# 37                               0                                0
# 41                               0                                0
# 42                               0                                1
# 43                               0                                0
# 44                               0                                0
#
#     Kensington Market / Chinatown / Grange Park  Lawrence Park  \
# 37                                            0              0
# 41                                            0              0
# 42                                            0              0
# 43                                            0              0
# 44                                            0              1
#
#     Little Portugal / Trinity  Moore Park / Summerhill East  \
# 37                          0                             0
# 41                          0                             0
# 42                          0                             0
# 43                          0                             0
# 44                          0                             0
#
#     North Toronto West  Parkdale / Roncesvalles  \
# 37                   0                        0
# 41                   0                        0
# 42                   0                        0
# 43                   0                        0
# 44                   0                        0
#
#     Queen's Park / Ontario Provincial Government  Regent Park / Harbourfront  \
# 37                                             0                           0
# 41                                             0                           0
# 42                                             0                           0
# 43                                             0                           0
# 44                                             0                           0
#
#     Richmond / Adelaide / King  Rosedale  Roselawn  Runnymede / Swansea  \
# 37                           0         0         0                    0
# 41                           0         0         0                    0
# 42                           0         0         0                    0
# 43                           0         0         0                    0
# 44                           0         0         0                    0
#
#     St. James Town  St. James Town / Cabbagetown  Stn A PO Boxes  \
# 37               0                             0               0
# 41               0                             0               0
# 42               0                             0               0
# 43               0                             0               0
# 44               0                             0               0
#
#     Studio District  \
# 37                0
# 41                0
# 42                0
# 43                1
# 44                0
#
#     Summerhill West / Rathnelly / South Hill / Forest Hill SE / Deer Park  \
# 37                                                  0
# 41                                                  0
# 42                                                  0
# 43                                                  0
# 44                                                  0
#
#     The Annex / North Midtown / Yorkville  The Beaches  \
# 37                                      0            1
# 41                                      0            0
# 42                                      0            0
# 43                                      0            0
# 44                                      0            0
#
#     The Danforth West / Riverdale  Toronto Dominion Centre / Design Exchange  \
# 37                              0                                          0
# 41                              1                                          0
# 42                              0                                          0
# 43                              0                                          0
# 44                              0                                          0
#
#     University of Toronto / Harbord
# 37                                0
# 41                                0
# 42                                0
# 43                                0
# 44                                0

# %%
df_grouped =df_onehot.groupby('Borough').mean().reset_index()
df_grouped
# Out:
#             Borough  Berczy Park  \
# 0   Central Toronto     0.000000
# 1  Downtown Toronto     0.052632
# 2      East Toronto     0.000000
# 3      West Toronto     0.000000
#
#    Brockton / Parkdale Village / Exhibition Place  \
# 0                                        0.000000
# 1                                        0.000000
# 2                                        0.000000
# 3                                        0.166667
#
#    Business reply mail Processing Centre  \
# 0                                    0.0
# 1                                    0.0
# 2                                    0.2
# 3                                    0.0
#
#    CN Tower / King and Spadina / Railway Lands / Harbourfront West / Bathurst Quay / South Niagara / Island airport  \
# 0                                           0.000000
# 1                                           0.052632
# 2                                           0.000000
# 3                                           0.000000
#
#    Central Bay Street  Christie  Church and Wellesley  \
# 0            0.000000  0.000000              0.000000
# 1            0.052632  0.052632              0.052632
# 2            0.000000  0.000000              0.000000
# 3            0.000000  0.000000              0.000000
#
#    Commerce Court / Victoria Hotel  Davisville  Davisville North  \
# 0                         0.000000    0.111111          0.111111
# 1                         0.052632    0.000000          0.000000
# 2                         0.000000    0.000000          0.000000
# 3                         0.000000    0.000000          0.000000
#
#    Dufferin / Dovercourt Village  First Canadian Place / Underground city  \
# 0                       0.000000                                 0.000000
# 1                       0.000000                                 0.052632
# 2                       0.000000                                 0.000000
# 3                       0.166667                                 0.000000
#
#    Forest Hill North & West  Garden District / Ryerson  \
# 0                  0.111111                   0.000000
# 1                  0.000000                   0.052632
# 2                  0.000000                   0.000000
# 3                  0.000000                   0.000000
#
#    Harbourfront East / Union Station / Toronto Islands  \
# 0                                           0.000000
# 1                                           0.052632
# 2                                           0.000000
# 3                                           0.000000
#
#    High Park / The Junction South  India Bazaar / The Beaches West  \
# 0                        0.000000                              0.0
# 1                        0.000000                              0.0
# 2                        0.000000                              0.2
# 3                        0.166667                              0.0
#
#    Kensington Market / Chinatown / Grange Park  Lawrence Park  \
# 0                                     0.000000       0.111111
# 1                                     0.052632       0.000000
# 2                                     0.000000       0.000000
# 3                                     0.000000       0.000000
#
#    Little Portugal / Trinity  Moore Park / Summerhill East  \
# 0                   0.000000                      0.111111
# 1                   0.000000                      0.000000
# 2                   0.000000                      0.000000
# 3                   0.166667                      0.000000
#
#    North Toronto West  Parkdale / Roncesvalles  \
# 0            0.111111                 0.000000
# 1            0.000000                 0.000000
# 2            0.000000                 0.000000
# 3            0.000000                 0.166667
#
#    Queen's Park / Ontario Provincial Government  Regent Park / Harbourfront  \
# 0                                      0.000000                    0.000000
# 1                                      0.052632                    0.052632
# 2                                      0.000000                    0.000000
# 3                                      0.000000                    0.000000
#
#    Richmond / Adelaide / King  Rosedale  Roselawn  Runnymede / Swansea  \
# 0                    0.000000  0.000000  0.111111             0.000000
# 1                    0.052632  0.052632  0.000000             0.000000
# 2                    0.000000  0.000000  0.000000             0.000000
# 3                    0.000000  0.000000  0.000000             0.166667
#
#    St. James Town  St. James Town / Cabbagetown  Stn A PO Boxes  \
# 0        0.000000                      0.000000        0.000000
# 1        0.052632                      0.052632        0.052632
# 2        0.000000                      0.000000        0.000000
# 3        0.000000                      0.000000        0.000000
#
#    Studio District  \
# 0              0.0
# 1              0.0
# 2              0.2
# 3              0.0
#
#    Summerhill West / Rathnelly / South Hill / Forest Hill SE / Deer Park  \
# 0                                           0.111111
# 1                                           0.000000
# 2                                           0.000000
# 3                                           0.000000
#
#    The Annex / North Midtown / Yorkville  The Beaches  \
# 0                               0.111111          0.0
# 1                               0.000000          0.0
# 2                               0.000000          0.2
# 3                               0.000000          0.0
#
#    The Danforth West / Riverdale  Toronto Dominion Centre / Design Exchange  \
# 0                            0.0                                   0.000000
# 1                            0.0                                   0.052632
# 2                            0.2                                   0.000000
# 3                            0.0                                   0.000000
#
#    University of Toronto / Harbord
# 0                         0.000000
# 1                         0.052632
# 2                         0.000000
# 3                         0.000000

# %%
num_top_venues = 5

for hood in df_grouped['Borough']:
    print("----"+hood+"----")
    temp = df_grouped[df_grouped['Borough'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    #print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    #print('\n')
# Out:
# ----Central Toronto----
# ----Downtown Toronto----
# ----East Toronto----
# ----West Toronto----

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Borough']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Borough'] =df_grouped['Borough']

for ind in np.arange(df_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(df_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#             Borough            1st Most Common Venue  \
# 0   Central Toronto                         Roselawn
# 1  Downtown Toronto  University of Toronto / Harbord
# 2      East Toronto  India Bazaar / The Beaches West
# 3      West Toronto        Little Portugal / Trinity
#
#            2nd Most Common Venue  \
# 0                     Davisville
# 1     Regent Park / Harbourfront
# 2  The Danforth West / Riverdale
# 3  Dufferin / Dovercourt Village
#
#                                3rd Most Common Venue  \
# 0                                      Lawrence Park
# 1  CN Tower / King and Spadina / Railway Lands / ...
# 2                                        The Beaches
# 3                     High Park / The Junction South
#
#                    4th Most Common Venue  \
# 0  The Annex / North Midtown / Yorkville
# 1                     Central Bay Street
# 2  Business reply mail Processing Centre
# 3                Parkdale / Roncesvalles
#
#                                5th Most Common Venue  \
# 0  Summerhill West / Rathnelly / South Hill / For...
# 1                                           Christie
# 2                                    Studio District
# 3                                Runnymede / Swansea
#
#                             6th Most Common Venue  \
# 0                    Moore Park / Summerhill East
# 1                            Church and Wellesley
# 2                                Davisville North
# 3  Brockton / Parkdale Village / Exhibition Place
#
#              7th Most Common Venue  \
# 0               North Toronto West
# 1  Commerce Court / Victoria Hotel
# 2   High Park / The Junction South
# 3               Central Bay Street
#
#                                8th Most Common Venue  \
# 0                           Forest Hill North & West
# 1            First Canadian Place / Underground city
# 2  Harbourfront East / Union Station / Toronto Is...
# 3                                           Christie
#
#        9th Most Common Venue  \
# 0           Davisville North
# 1  Garden District / Ryerson
# 2  Garden District / Ryerson
# 3       Church and Wellesley
#
#                               10th Most Common Venue
# 0                          Garden District / Ryerson
# 1  Harbourfront East / Union Station / Toronto Is...
# 2                           Forest Hill North & West
# 3                    Commerce Court / Victoria Hotel

# %%
# set number of clusters
kclusters = 4

df_grouped_clustering = df_grouped.drop('Borough', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(df_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([0, 3, 1, 2], dtype=int32)

# %%
# add clustering labels
#neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

df_merged = df_tor1

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
df_merged = df_merged.join(neighborhoods_venues_sorted.set_index('Borough'), on='Borough')

df_merged.head() # check the last columns!
# Out:
#    Postal code          Borough                     Neighborhood  \
# 37         M4E     East Toronto                      The Beaches
# 41         M4K     East Toronto    The Danforth West / Riverdale
# 42         M4L     East Toronto  India Bazaar / The Beaches West
# 43         M4M     East Toronto                  Studio District
# 44         M4N  Central Toronto                    Lawrence Park
#
#              Latitude           Longitude  Cluster Labels  \
# 37  43.67635739999999         -79.2930312               1
# 41         43.6795571          -79.352188               1
# 42         43.6689985  -79.31557159999998               1
# 43         43.6595255          -79.340923               1
# 44         43.7280205         -79.3887901               0
#
#               1st Most Common Venue          2nd Most Common Venue  \
# 37  India Bazaar / The Beaches West  The Danforth West / Riverdale
# 41  India Bazaar / The Beaches West  The Danforth West / Riverdale
# 42  India Bazaar / The Beaches West  The Danforth West / Riverdale
# 43  India Bazaar / The Beaches West  The Danforth West / Riverdale
# 44                         Roselawn                     Davisville
#
#    3rd Most Common Venue                  4th Most Common Venue  \
# 37           The Beaches  Business reply mail Processing Centre
# 41           The Beaches  Business reply mail Processing Centre
# 42           The Beaches  Business reply mail Processing Centre
# 43           The Beaches  Business reply mail Processing Centre
# 44         Lawrence Park  The Annex / North Midtown / Yorkville
#
#                                 5th Most Common Venue  \
# 37                                    Studio District
# 41                                    Studio District
# 42                                    Studio District
# 43                                    Studio District
# 44  Summerhill West / Rathnelly / South Hill / For...
#
#            6th Most Common Venue           7th Most Common Venue  \
# 37              Davisville North  High Park / The Junction South
# 41              Davisville North  High Park / The Junction South
# 42              Davisville North  High Park / The Junction South
# 43              Davisville North  High Park / The Junction South
# 44  Moore Park / Summerhill East              North Toronto West
#
#                                 8th Most Common Venue  \
# 37  Harbourfront East / Union Station / Toronto Is...
# 41  Harbourfront East / Union Station / Toronto Is...
# 42  Harbourfront East / Union Station / Toronto Is...
# 43  Harbourfront East / Union Station / Toronto Is...
# 44                           Forest Hill North & West
#
#         9th Most Common Venue     10th Most Common Venue
# 37  Garden District / Ryerson   Forest Hill North & West
# 41  Garden District / Ryerson   Forest Hill North & West
# 42  Garden District / Ryerson   Forest Hill North & West
# 43  Garden District / Ryerson   Forest Hill North & West
# 44           Davisville North  Garden District / Ryerson

# %%
df_merged.loc[df_merged['Cluster Labels'] == 0, df_merged.columns[[1] + list(range(4, df_merged.shape[1]))]].head(1)
# Out:
#             Borough    Longitude  Cluster Labels 1st Most Common Venue  \
# 44  Central Toronto  -79.3887901               0              Roselawn
#
#    2nd Most Common Venue 3rd Most Common Venue  \
# 44            Davisville         Lawrence Park
#
#                     4th Most Common Venue  \
# 44  The Annex / North Midtown / Yorkville
#
#                                 5th Most Common Venue  \
# 44  Summerhill West / Rathnelly / South Hill / For...
#
#            6th Most Common Venue 7th Most Common Venue  \
# 44  Moore Park / Summerhill East    North Toronto West
#
#        8th Most Common Venue 9th Most Common Venue     10th Most Common Venue
# 44  Forest Hill North & West      Davisville North  Garden District / Ryerson

# %%
df_merged.loc[df_merged['Cluster Labels'] == 1, df_merged.columns[[1] + list(range(4, df_merged.shape[1]))]].head(1)
# Out:
#          Borough    Longitude  Cluster Labels  \
# 37  East Toronto  -79.2930312               1
#
#               1st Most Common Venue          2nd Most Common Venue  \
# 37  India Bazaar / The Beaches West  The Danforth West / Riverdale
#
#    3rd Most Common Venue                  4th Most Common Venue  \
# 37           The Beaches  Business reply mail Processing Centre
#
#    5th Most Common Venue 6th Most Common Venue  \
# 37       Studio District      Davisville North
#
#              7th Most Common Venue  \
# 37  High Park / The Junction South
#
#                                 8th Most Common Venue  \
# 37  Harbourfront East / Union Station / Toronto Is...
#
#         9th Most Common Venue    10th Most Common Venue
# 37  Garden District / Ryerson  Forest Hill North & West

# %%
df_merged.loc[df_merged['Cluster Labels'] == 2, df_merged.columns[[1] + list(range(4, df_merged.shape[1]))]].head(1)
# Out:
#          Borough    Longitude  Cluster Labels      1st Most Common Venue  \
# 76  West Toronto  -79.4422593               2  Little Portugal / Trinity
#
#             2nd Most Common Venue           3rd Most Common Venue  \
# 76  Dufferin / Dovercourt Village  High Park / The Junction South
#
#       4th Most Common Venue 5th Most Common Venue  \
# 76  Parkdale / Roncesvalles   Runnymede / Swansea
#
#                              6th Most Common Venue 7th Most Common Venue  \
# 76  Brockton / Parkdale Village / Exhibition Place    Central Bay Street
#
#    8th Most Common Venue 9th Most Common Venue  \
# 76              Christie  Church and Wellesley
#
#              10th Most Common Venue
# 76  Commerce Court / Victoria Hotel

# %%
df_merged.loc[df_merged['Cluster Labels'] == 3, df_merged.columns[[1] + list(range(4, df_merged.shape[1]))]].head(1)
# Out:
#              Borough           Longitude  Cluster Labels  \
# 50  Downtown Toronto  -79.37752940000001               3
#
#               1st Most Common Venue       2nd Most Common Venue  \
# 50  University of Toronto / Harbord  Regent Park / Harbourfront
#
#                                 3rd Most Common Venue 4th Most Common Venue  \
# 50  CN Tower / King and Spadina / Railway Lands / ...    Central Bay Street
#
#    5th Most Common Venue 6th Most Common Venue  \
# 50              Christie  Church and Wellesley
#
#               7th Most Common Venue                    8th Most Common Venue  \
# 50  Commerce Court / Victoria Hotel  First Canadian Place / Underground city
#
#         9th Most Common Venue  \
# 50  Garden District / Ryerson
#
#                                10th Most Common Venue
# 50  Harbourfront East / Union Station / Toronto Is...

# %%
# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     branca-0.4.0               |             py_0          26 KB  conda-forge
#     brotlipy-0.7.0             |py36h8c4c3a4_1000         346 KB  conda-forge
#     chardet-3.0.4              |py36h9f0ad1d_1006         188 KB  conda-forge
#     cryptography-2.9.2         |   py36h45558ae_0         613 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     pandas-1.0.3               |   py36h830a2c2_1        11.1 MB  conda-forge
#     pysocks-1.7.1              |   py36h9f0ad1d_1          27 KB  conda-forge
#     pytz-2020.1                |     pyh9f0ad1d_0         227 KB  conda-forge
#     toolz-0.10.0               |             py_0          46 KB  conda-forge
#     urllib3-1.25.9             |             py_0          92 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        13.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   altair             conda-forge/noarch::altair-4.1.0-py_1
#   attrs              conda-forge/noarch::attrs-19.3.0-py_0
#   branca             conda-forge/noarch::branca-0.4.0-py_0
#   brotlipy           conda-forge/linux-64::brotlipy-0.7.0-py36h8c4c3a4_1000
#   chardet            conda-forge/linux-64::chardet-3.0.4-py36h9f0ad1d_1006
#   cryptography       conda-forge/linux-64::cryptography-2.9.2-py36h45558ae_0
#   entrypoints        conda-forge/linux-64::entrypoints-0.3-py36h9f0ad1d_1001
#   folium             conda-forge/noarch::folium-0.5.0-py_0
#   idna               conda-forge/noarch::idna-2.9-py_1
#   importlib-metadata conda-forge/linux-64::importlib-metadata-1.6.0-py36h9f0ad1d_0
#   importlib_metadata conda-forge/noarch::importlib_metadata-1.6.0-0
#   jinja2             conda-forge/noarch::jinja2-2.11.2-pyh9f0ad1d_0
#   jsonschema         conda-forge/linux-64::jsonschema-3.2.0-py36h9f0ad1d_1
#   markupsafe         conda-forge/linux-64::markupsafe-1.1.1-py36h8c4c3a4_1
#   pandas             conda-forge/linux-64::pandas-1.0.3-py36h830a2c2_1
#   pyopenssl          conda-forge/noarch::pyopenssl-19.1.0-py_1
#   pyrsistent         conda-forge/linux-64::pyrsistent-0.16.0-py36h8c4c3a4_0
#   pysocks            conda-forge/linux-64::pysocks-1.7.1-py36h9f0ad1d_1
#   pytz               conda-forge/noarch::pytz-2020.1-pyh9f0ad1d_0
#   requests           conda-forge/noarch::requests-2.23.0-pyh8c360ce_2
#   toolz              conda-forge/noarch::toolz-0.10.0-py_0
#   urllib3            conda-forge/noarch::urllib3-1.25.9-py_0
#   vincent            conda-forge/noarch::vincent-0.4.4-py_1
#   zipp               conda-forge/noarch::zipp-3.1.0-py_0
#
#
#
# Downloading and Extracting Packages
# pysocks-1.7.1        | 27 KB     | ##################################### | 100%
# toolz-0.10.0         | 46 KB     | ##################################### | 100%
# pytz-2020.1          | 227 KB    | ##################################### | 100%
# chardet-3.0.4        | 188 KB    | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# urllib3-1.25.9       | 92 KB     | ##################################### | 100%
# cryptography-2.9.2   | 613 KB    | ##################################### | 100%
# brotlipy-0.7.0       | 346 KB    | ##################################### | 100%
# pandas-1.0.3         | 11.1 MB   | ##################################### | 100%
# altair-4.1.0         | 614 KB    | ##################################### | 100%
# branca-0.4.0         | 26 KB     | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
# create map
map_clusters = folium.Map(location=[43.6532, -79.3832], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []

       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
